# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Rufei**
#
# Data Scientist

# %% [markdown]
# *I want to use the power of data to create value for the society.*

# %% [markdown]
# ### To evaluate whether a statement is true

# %%
print(3>5)
# Out:
# False

# %% [markdown]
# Test horizontal rules:
#
# ---
#
# Test table
#
# | Sales| Cost| Revenue|
# | ------------- |:-------------:| -----:|
# |100|90|10|
#
# * This
# * is
# * bulleted list
