# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Diego Jesús Vega Garbanzo**
# TRACOPA Parcel Delivery Service

# %% [markdown]
# _I'm interested in data science because I believe it's the future of data_

# %% [markdown]
# ### x is equal to Hello World and then print the contents of x.

# %%
x = "Hello Word"
print (x)
# Out:
# Hello Word

# %% [markdown]
# 1. One
# 1. Two
# 1. Three
#
# __[IBM - United States](https://www.ibm.com/cr-es/?ar=1)__
#
# | Hello| Word |
# |------|------|
# |Hello | Word |
